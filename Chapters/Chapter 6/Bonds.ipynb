# %% [markdown]
# You need a 6.5% annual return to justify the risks of the following financial contract:\
# you will receive annual payments of $50 for five years and one lump sum payment of $1,000 in five years.
#
# What price should you pay for the contract?

# %% [markdown]
# $$
# \begin{align*}
# i &  : \text{Interest Rate (\%)}\\
# r &  : \text{Required Rate of Return (\%)}\\
# \end{align*}
# $$

# %% [markdown]
# The price of a bond is the present value of all cash flows generated by the bond\
# (i.e. coupons and face value) discounted at the required rate of return.
#
# $$
# PV = \frac{cpn}{(1+r)^1} + \frac{cpn}{(1+r)^2} + \dots + \frac{cpn + par}{(1+r)^t}
#
# $$
#
#
# $$
# \newline
# \begin{align*}
# t &  : \text{Number of Periods Cash Payment is Received}\\
# \end{align*}
# $$

# %%
# For annuity
pmt = 50
r = .065
t = 5
p_v = pmt * (1/r - 1/(r(1+r)**t))
p_v += 1000/(1+r)**t

print(f'PV = ${p_v:.2f}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 r = .065
#       4 t = 5
# ----> 5 p_v = pmt * (1/r - 1/(r(1+r)**t))
#       6 p_v += 1000/(1+r)**t
#       8 print(f'PV = ${p_v:.2f}')
#
# TypeError: 'float' object is not callable
